# %% [markdown]
# #Environment Check

# %%
import gymnasium as gym
import torch as th
import numpy as np
from twsbr_env.envs import TwsbrEnv  # Import environment
from stable_baselines3 import SAC, A2C, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, BaseCallback
from stable_baselines3.common.logger import configure

# Buat environment
env = gym.make("TwsbrEnv-v0", render_mode=None, action_type="continuous")

# Callback untuk mengupdate ent_coef selama training
class EntropyScheduleCallback(BaseCallback):
    def __init__(self, start_ent=0.05, end_ent=0.001, total_timesteps=1e5, verbose=0):
        super().__init__(verbose)
        self.start_ent = start_ent
        self.end_ent = end_ent
        self.total_timesteps = total_timesteps

    def _on_step(self) -> bool:
        progress = self.num_timesteps / self.total_timesteps
        if progress < 0.1:
            self.model.ent_coef = 0.2
        elif progress < 0.25:
            self.model.ent_coef = 0.1
        elif progress < 0.5:
            self.model.ent_coef = 0.05
        else:
            self.model.ent_coef = 0.001
        return True

# Pilih Algoritma (SAC, A2C, PPO)
algorithm = "PPO"  # Pilihan: "SAC", "PPO", "A2C"

if algorithm == "PPO":
    model = PPO(
        "MlpPolicy", env,
        n_steps=2048, batch_size=128, n_epochs=10,
        target_kl=0.05,
        ent_coef=0.1,
        verbose=1,
    )
elif algorithm == "A2C":
    model = A2C(
        "MlpPolicy", env,
        learning_rate=lr_schedule, gamma=0.99,
        ent_coef=0.1,
        
        verbose=1,
    )
else:  # Default ke SAC
    model = SAC(
        "MlpPolicy", env,
        buffer_size=int(1e6),
       
        use_sde=True, ent_coef="auto_0.1",
        verbose=1,
    )

# Setup TensorBoard logger
#log_dir = "./tensorboard_logs/"
#logger = configure(log_dir, ['tensorboard'])
#model.set_logger(logger)

# Setup callbacks
total_timesteps_learning = 1_000_000
save_freq_learning = total_timesteps_learning / 10
checkpoint_callback = CheckpointCallback(save_freq=save_freq_learning, save_path='./models/', name_prefix=f'{algorithm.lower()}_checkpoint')
eval_callback = EvalCallback(env, best_model_save_path="./logs/", log_path="./logs/", eval_freq=save_freq_learning, n_eval_episodes=5, deterministic=True)
entropy_callback = EntropyScheduleCallback(start_ent=0.1, end_ent=0.001, total_timesteps=total_timesteps_learning)

# Training model
model.learn(total_timesteps=total_timesteps_learning, callback=[checkpoint_callback, eval_callback, entropy_callback])

# Simpan model
model.save("twsbr_ppo")
print("Training is finished")

# Evaluasi model
n_eval_episodes = 10
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=n_eval_episodes, render=False)
print(f"Mean Reward over {n_eval_episodes} episodes: {mean_reward:.2f} +/- {std_reward:.2f}")

env.close()
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.53     |
# |    ep_rew_mean     | -25.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 7        |
# |    iterations      | 1        |
# |    time_elapsed    | 271      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | -25.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 2           |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011504446 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.000977   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 1.03        |
# |    value_loss           | 315         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.4         |
# |    ep_rew_mean          | -25.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 3            |
# |    time_elapsed         | 789          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057244473 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | -0.0361      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00734     |
# |    std                  | 1.06         |
# |    value_loss           | 192          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | -25.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 4          |
# |    time_elapsed         | 1005       |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01021064 |
# |    clip_fraction        | 0.0763     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | -0.129     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.8       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0132    |
# |    std                  | 1.1        |
# |    value_loss           | 67.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.8       |
# |    ep_rew_mean          | -25.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 5          |
# |    time_elapsed         | 1208       |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02398593 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | -0.0746    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.19       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 1.18       |
# |    value_loss           | 14.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18          |
# |    ep_rew_mean          | -26.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 6           |
# |    time_elapsed         | 1379        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024457524 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | -0.0132     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.559       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00921    |
# |    std                  | 1.29        |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19          |
# |    ep_rew_mean          | -26.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 7           |
# |    time_elapsed         | 1544        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013311227 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | -0.0209     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.554       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00337    |
# |    std                  | 1.37        |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -26.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 8           |
# |    time_elapsed         | 1692        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011739723 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | -0.0114     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.521       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0062     |
# |    std                  | 1.44        |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -27.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 9           |
# |    time_elapsed         | 1838        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008319501 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | -0.00731    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.516       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00424    |
# |    std                  | 1.5         |
# |    value_loss           | 2.53        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.8       |
# |    ep_rew_mean          | -26.9      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 10         |
# |    time_elapsed         | 1977       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01014385 |
# |    clip_fraction        | 0.0852     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | -0.00591   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.415      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00694   |
# |    std                  | 1.56       |
# |    value_loss           | 2.67       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | -27.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 11          |
# |    time_elapsed         | 2113        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010894248 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | -0.0072     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.544       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00548    |
# |    std                  | 1.62        |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.6        |
# |    ep_rew_mean          | -27.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 2239        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010391459 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | -0.00455    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.456       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00751    |
# |    std                  | 1.66        |
# |    value_loss           | 2.5         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.5       |
# |    ep_rew_mean          | -27.8      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 13         |
# |    time_elapsed         | 2367       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00647618 |
# |    clip_fraction        | 0.0569     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.89      |
# |    explained_variance   | -0.00188   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.944      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00305   |
# |    std                  | 1.72       |
# |    value_loss           | 3.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.8        |
# |    ep_rew_mean          | -28.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 14          |
# |    time_elapsed         | 2485        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008481238 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | -0.00436    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.488       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0042     |
# |    std                  | 1.78        |
# |    value_loss           | 3.11        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 28.6      |
# |    ep_rew_mean          | -27.9     |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 11        |
# |    iterations           | 15        |
# |    time_elapsed         | 2615      |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0093396 |
# |    clip_fraction        | 0.0706    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.03     |
# |    explained_variance   | -0.00593  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.818     |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -0.00588  |
# |    std                  | 1.85      |
# |    value_loss           | 3.16      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | -28.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 16          |
# |    time_elapsed         | 2742        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008477644 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | -0.00203    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.656       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00432    |
# |    std                  | 1.92        |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.9        |
# |    ep_rew_mean          | -28.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 17          |
# |    time_elapsed         | 2857        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009865304 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -0.00326    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.53        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00661    |
# |    std                  | 2           |
# |    value_loss           | 3.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | -28.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 18           |
# |    time_elapsed         | 2981         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0064653456 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00245     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.715        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 2.07         |
# |    value_loss           | 3.15         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | -27.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 19          |
# |    time_elapsed         | 3107        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007138049 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.00167    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.568       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00269    |
# |    std                  | 2.15        |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.6        |
# |    ep_rew_mean          | -27.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 20          |
# |    time_elapsed         | 3234        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005735274 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | -0.000569   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.96        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 2.21        |
# |    value_loss           | 3.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.5        |
# |    ep_rew_mean          | -28.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 21          |
# |    time_elapsed         | 3348        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009274166 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | -0.000767   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.842       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00542    |
# |    std                  | 2.29        |
# |    value_loss           | 3.45        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.2         |
# |    ep_rew_mean          | -29.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 22           |
# |    time_elapsed         | 3456         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0074381884 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.53        |
# |    explained_variance   | -0.000835    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.912        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 2.36         |
# |    value_loss           | 3.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.4         |
# |    ep_rew_mean          | -28.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 23           |
# |    time_elapsed         | 3575         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0068468573 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -0.00235     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.918        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00482     |
# |    std                  | 2.46         |
# |    value_loss           | 3.72         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 32.4       |
# |    ep_rew_mean          | -28.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 24         |
# |    time_elapsed         | 3692       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00795524 |
# |    clip_fraction        | 0.054      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.68      |
# |    explained_variance   | -0.0014    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.603      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0045    |
# |    std                  | 2.56       |
# |    value_loss           | 3.52       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | -28.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 25           |
# |    time_elapsed         | 3814         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0059309974 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.75        |
# |    explained_variance   | 2.42e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.702        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 2.64         |
# |    value_loss           | 3.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.8         |
# |    ep_rew_mean          | -28.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 26           |
# |    time_elapsed         | 3930         |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0055451165 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.82        |
# |    explained_variance   | -0.00046     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.662        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 2.73         |
# |    value_loss           | 3.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.8         |
# |    ep_rew_mean          | -28.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 27           |
# |    time_elapsed         | 4041         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0076634493 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.89        |
# |    explained_variance   | -0.00313     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.725        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00418     |
# |    std                  | 2.85         |
# |    value_loss           | 3.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.8         |
# |    ep_rew_mean          | -28.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 28           |
# |    time_elapsed         | 4150         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0052229534 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.96        |
# |    explained_variance   | -0.00108     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.827        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 2.94         |
# |    value_loss           | 3.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.8         |
# |    ep_rew_mean          | -28.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 29           |
# |    time_elapsed         | 4267         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0059958454 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | -0.000961    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.597        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 3.06         |
# |    value_loss           | 3.81         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.6        |
# |    ep_rew_mean          | -28.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 30          |
# |    time_elapsed         | 4379        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005420759 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.000189    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.538       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 3.17        |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | -28.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 31           |
# |    time_elapsed         | 4498         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0068367617 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | -0.0013      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.916        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00379     |
# |    std                  | 3.28         |
# |    value_loss           | 3.78         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.9        |
# |    ep_rew_mean          | -28.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 32          |
# |    time_elapsed         | 4617        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005440679 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | -0.00186    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.918       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00505    |
# |    std                  | 3.39        |
# |    value_loss           | 3.73        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | -28.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 33           |
# |    time_elapsed         | 4731         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0051338556 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.31        |
# |    explained_variance   | -0.00193     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.868        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 3.51         |
# |    value_loss           | 3.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | -28.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 34          |
# |    time_elapsed         | 4845        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005485488 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.000868    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.512       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00266    |
# |    std                  | 3.62        |
# |    value_loss           | 3.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.4         |
# |    ep_rew_mean          | -28.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 35           |
# |    time_elapsed         | 4962         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0039788447 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.44        |
# |    explained_variance   | 0.00425      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.897        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000757    |
# |    std                  | 3.72         |
# |    value_loss           | 3.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.4         |
# |    ep_rew_mean          | -28.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 36           |
# |    time_elapsed         | 5075         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0065539666 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.596        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00535     |
# |    std                  | 3.85         |
# |    value_loss           | 3.55         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.7         |
# |    ep_rew_mean          | -28.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 37           |
# |    time_elapsed         | 5184         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0062452657 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.56        |
# |    explained_variance   | -0.011       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.446        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0045      |
# |    std                  | 3.97         |
# |    value_loss           | 3.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37           |
# |    ep_rew_mean          | -28.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 38           |
# |    time_elapsed         | 5295         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0041141096 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.00174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.916        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 4.12         |
# |    value_loss           | 3.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34           |
# |    ep_rew_mean          | -28.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 39           |
# |    time_elapsed         | 5414         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0065378305 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.0056       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.692        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0031      |
# |    std                  | 4.27         |
# |    value_loss           | 3.98         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | -28.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 40          |
# |    time_elapsed         | 5592        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005491888 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | -0.00788    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.786       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00187    |
# |    std                  | 4.38        |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.4        |
# |    ep_rew_mean          | -28.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 41          |
# |    time_elapsed         | 5762        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004812666 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | -0.00379    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.67        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00097    |
# |    std                  | 4.5         |
# |    value_loss           | 3.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.9         |
# |    ep_rew_mean          | -28.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 42           |
# |    time_elapsed         | 5943         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0058841095 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.88        |
# |    explained_variance   | -0.00865     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.232        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 4.64         |
# |    value_loss           | 3.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.3        |
# |    ep_rew_mean          | -28.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 43          |
# |    time_elapsed         | 6123        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004788367 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.94       |
# |    explained_variance   | -0.033      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.567       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 4.78        |
# |    value_loss           | 3.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.1         |
# |    ep_rew_mean          | -28.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 44           |
# |    time_elapsed         | 6300         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0045407824 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -0.00482     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.442        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 4.9          |
# |    value_loss           | 3.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.7         |
# |    ep_rew_mean          | -27.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 45           |
# |    time_elapsed         | 6483         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0060027405 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.05        |
# |    explained_variance   | -0.00375     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.767        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 5.04         |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.8        |
# |    ep_rew_mean          | -28.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 46          |
# |    time_elapsed         | 6665        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006046688 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.11       |
# |    explained_variance   | -0.00798    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.538       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00225    |
# |    std                  | 5.22        |
# |    value_loss           | 3.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | -28.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 47           |
# |    time_elapsed         | 6840         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0059128916 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.18        |
# |    explained_variance   | -0.000585    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.525        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00183     |
# |    std                  | 5.41         |
# |    value_loss           | 3.49         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | -28.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 48          |
# |    time_elapsed         | 7014        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006162579 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.26       |
# |    explained_variance   | -0.0161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 5.63        |
# |    value_loss           | 3.38        |
# -----------------------------------------
# c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=100000, episode_reward=-26.97 +/- 1.83
# Episode length: 27.80 +/- 15.20
# Success rate: 0.00%
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 27.8        |
# |    mean_reward          | -27         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.006928888 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.33       |
# |    explained_variance   | 0.00746     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.47        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00325    |
# |    std                  | 5.83        |
# ...
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 474          |
# |    time_elapsed         | 59899        |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0029481729 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.803        |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.0023      |
# |    std                  | 39.1         |
# |    value_loss           | 2.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39          |
# |    ep_rew_mean          | -27         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 475         |
# |    time_elapsed         | 60054       |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.003981308 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00421    |
# |    std                  | 38.9        |
# |    value_loss           | 2.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.5         |
# |    ep_rew_mean          | -27.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 476          |
# |    time_elapsed         | 60212        |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0017217018 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00132     |
# |    std                  | 38.9         |
# |    value_loss           | 1.94         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.9         |
# |    ep_rew_mean          | -27.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 477          |
# |    time_elapsed         | 60366        |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0042456845 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0044      |
# |    std                  | 38.7         |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.4         |
# |    ep_rew_mean          | -27.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 478          |
# |    time_elapsed         | 60526        |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0031673508 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00356     |
# |    std                  | 39.2         |
# |    value_loss           | 2.43         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.3         |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 479          |
# |    time_elapsed         | 60687        |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0028267396 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.559        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00344     |
# |    std                  | 39.2         |
# |    value_loss           | 2.64         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | -26.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 480         |
# |    time_elapsed         | 60848       |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.004135105 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00381    |
# |    std                  | 39.6        |
# |    value_loss           | 2.3         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39         |
# |    ep_rew_mean          | -26.9      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 481        |
# |    time_elapsed         | 61011      |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.00335054 |
# |    clip_fraction        | 0.026      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.2      |
# |    explained_variance   | 0.587      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.00358   |
# |    std                  | 39.3       |
# |    value_loss           | 2.51       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.6        |
# |    ep_rew_mean          | -26.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 482         |
# |    time_elapsed         | 61170       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.003275103 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.869       |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 39.1        |
# |    value_loss           | 2.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40          |
# |    ep_rew_mean          | -27         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 483         |
# |    time_elapsed         | 61327       |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.003616326 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.905       |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 39.4        |
# |    value_loss           | 2.45        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.9         |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 484          |
# |    time_elapsed         | 61487        |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0026762313 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07         |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00243     |
# |    std                  | 38.9         |
# |    value_loss           | 2.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.5         |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 485          |
# |    time_elapsed         | 61646        |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0058921557 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.864        |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00523     |
# |    std                  | 38.8         |
# |    value_loss           | 1.76         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.8         |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 486          |
# |    time_elapsed         | 61808        |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0022871098 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.1        |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.814        |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 38.2         |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.4         |
# |    ep_rew_mean          | -26.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 487          |
# |    time_elapsed         | 61969        |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0022920747 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.1        |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00323     |
# |    std                  | 38.2         |
# |    value_loss           | 2.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38           |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 488          |
# |    time_elapsed         | 62133        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0025558858 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.1        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00315     |
# |    std                  | 38.5         |
# |    value_loss           | 2.46         |
# ------------------------------------------
# Eval num_timesteps=1000000, episode_reward=-26.33 +/- 0.37
# Episode length: 28.20 +/- 6.88
# Success rate: 0.00%
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 28.2        |
# |    mean_reward          | -26.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    total_timesteps      | 1000000     |
# | train/                  |             |
# |    approx_kl            | 0.002980833 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 38.7        |
# |    value_loss           | 2.21        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | -27.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 16       |
# |    iterations      | 489      |
# |    time_elapsed    | 62302    |
# |    total_timesteps | 1001472  |
# ---------------------------------
# Training is finished
# Mean Reward over 10 episodes: -26.34 +/- 0.56

# %%
# -------------------------------------------------------------
# Inferensi dan evaluasi dengan custom evaluasi metrik (untuk PPO)
# -------------------------------------------------------------
import numpy as np  # Tambahkan numpy untuk analisis statistik
import gymnasium as gym
from twsbr_env.envs import TwsbrEnv  # Import environment
from stable_baselines3 import PPO

# Muat kembali lingkungan dan model
env = gym.make("TwsbrEnv-v0",
               render_mode="human",
               action_type="continuous"  # Action type
               )

model = PPO.load("twsbr_ppo")

# Mulai evaluasi
total_rewards = []
episode_lengths = []
episode_reward = 0
episode_length = 0

obs, info = env.reset()
terminated = False
truncated = False

for _ in range(10000):  # Jumlah langkah yang akan dilakukan selama evaluasi
    # Pilih tindakan berdasarkan model
    action, _states = model.predict(obs, deterministic=True)

    # Lakukan aksi di lingkungan
    obs, reward, terminated, truncated, info = env.step(action)
    
    episode_reward += reward
    episode_length += 1

    # Render visualisasi (jika diinginkan)
    # Reset episode jika selesai
    if terminated or truncated:
        #print(f"{episode_length} : {episode_reward} : {truncated} or {terminated} : {obs}")  # Uncomment for debugging
        total_rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        obs, info = env.reset()
        episode_reward = 0
        episode_length = 0

# Analisis hasil evaluasi
average_reward = np.mean(total_rewards)
average_length = np.mean(episode_lengths)

print(f"Average Reward per Episode: {average_reward:.2f}")
print(f"Average Episode Length: {average_length:.2f}")

# Menutup lingkungan
env.close()
