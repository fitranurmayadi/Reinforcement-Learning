# %%
import gymnasium as gym
import torch as th
from LunarLander3DEnv.envs import LunarLander3DEnv  # Pastikan environment sudah terdaftar (register)
# Import algoritma dari stable-baselines3
# Tambahkan library sb3-contrib jika menggunakan TRPO
from stable_baselines3 import PPO, A2C, DDPG, SAC, TD3
from sb3_contrib import TRPO

# TRPO tersedia dari sb3-contrib
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback

# Pilih algoritma yang ingin digunakan: "PPO", "A2C", "DDPG", "SAC", "TD3", atau "TRPO"
algorithm = "TD3"

# Buat environment
env = gym.make("LunarLander3DEnv-v0", render_mode=None)

# Inisialisasi model sesuai algoritma yang dipilih
model = None
if algorithm == "PPO":
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,  # Bisa diturunkan jika training terlalu lambat
        n_steps=2048,  # Lebih besar agar bisa menangkap lebih banyak trajektori
        batch_size=64,  # Cukup kecil untuk menjaga stabilitas
        n_epochs=10,  # Jumlah update per batch
        gamma=0.99,  # Discount factor untuk jangka panjang
        gae_lambda=0.95,  # Generalized Advantage Estimation
        clip_range=0.2,  # PPO Clipping
        ent_coef=0.01,  # Menambah eksplorasi dengan entropy loss
        vf_coef=0.5,  # Koefisien untuk fungsi nilai (value function)
        policy_kwargs=dict(net_arch=dict(pi=[256, 256], vf=[256, 256])),
        verbose=1,
        device="cuda" if th.cuda.is_available() else "cpu"
    )

elif algorithm == "SAC":
    model = SAC(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        buffer_size=500_000,  # Replay buffer lebih besar untuk kontrol kontinu
        batch_size=128,  # SAC lebih stabil dengan batch besar
        tau=0.005,  # Soft update factor
        gamma=0.99,
        ent_coef="auto_0.1",  # Entropy coefficient adaptif
        use_sde=True,  # State Dependent Exploration (untuk eksplorasi lebih baik)
        policy_kwargs=dict(net_arch=dict(pi=[256, 256], qf=[256, 256])),
        verbose=1,
    )

elif algorithm == "TD3":
    model = TD3(
        "MlpPolicy",
        env,
        learning_rate=1e-3,  # TD3 lebih cepat belajar dengan LR lebih tinggi
        buffer_size=500_000,
        batch_size=128,
        tau=0.005,
        gamma=0.99,
        policy_delay=2,  # Delay untuk update policy lebih stabil
        target_policy_noise=0.2,  # Tambahkan noise agar eksplorasi lebih baik
        target_noise_clip=0.5,
        policy_kwargs=dict(net_arch=[256, 256]),
        verbose=1,
    )
elif algorithm == "TRPO":
    model = TRPO(
        "MlpPolicy",
        env,
        learning_rate=1e-4,
        gamma=0.99,
        gae_lambda=0.95,
        max_kl=0.01,  # Batas maksimum perubahan policy
        ent_coef=0.01,
        vf_coef=0.5,
        policy_kwargs=dict(net_arch=[256, 256]),
        verbose=1,
    )

else:
    raise ValueError("Algoritma yang dipilih tidak didukung. Pilih salah satu: PPO, SAC, TD3, TRPO.")

# Setup callbacks untuk menyimpan model dan evaluasi secara berkala
total_timesteps_learning = 100_000

checkpoint_callback = CheckpointCallback(
    save_freq=int(total_timesteps_learning / 10),
    save_path='./models/',
    name_prefix=f'{algorithm}_checkpoint_v1_'
)
eval_callback = EvalCallback(
    env,
    best_model_save_path="./logs/",
    log_path="./logs/",
    eval_freq=total_timesteps_learning / 10,
    n_eval_episodes=10,
    deterministic=True,
)

# Mulai proses pelatihan
model.learn(total_timesteps=total_timesteps_learning, callback=[checkpoint_callback, eval_callback])

# Simpan model yang sudah dilatih
model.save(f"ll3d_{algorithm}")
print("Training is finished")

# Evaluasi agent
n_eval_episodes = 10
render = False  # Ubah ke True jika ingin melihat visualisasi evaluasi
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=n_eval_episodes, render=render)

print(f"Mean Reward over {n_eval_episodes} episodes: {mean_reward:.2f} +/- {std_reward:.2f}")

env.close()
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 524      |
# |    ep_rew_mean     | -1.8e+05 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 101      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2094     |
# | train/             |          |
# |    actor_loss      | 1.21e+03 |
# |    critic_loss     | 6.78e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1993     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 403       |
# |    ep_rew_mean     | -1.28e+05 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 102       |
# |    time_elapsed    | 31        |
# |    total_timesteps | 3227      |
# | train/             |           |
# |    actor_loss      | 1.76e+03  |
# |    critic_loss     | 3.26e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3126      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 287       |
# |    ep_rew_mean     | -9.14e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 98        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 3449      |
# | train/             |           |
# |    actor_loss      | 1.95e+03  |
# |    critic_loss     | 2.69e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3348      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | -7.6e+04 |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 95       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3825     |
# | train/             |          |
# |    actor_loss      | 2.08e+03 |
# |    critic_loss     | 2.7e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3724     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 225       |
# |    ep_rew_mean     | -7.12e+04 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 94        |
# |    time_elapsed    | 47        |
# |    total_timesteps | 4501      |
# | train/             |           |
# |    actor_loss      | 2.29e+03  |
# |    critic_loss     | 1.33e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4400      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 203       |
# |    ep_rew_mean     | -6.41e+04 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 92        |
# |    time_elapsed    | 52        |
# |    total_timesteps | 4883      |
# | train/             |           |
# |    actor_loss      | 2.51e+03  |
# |    critic_loss     | 6.64e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4782      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 181       |
# |    ep_rew_mean     | -5.68e+04 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 90        |
# |    time_elapsed    | 56        |
# |    total_timesteps | 5064      |
# | train/             |           |
# |    actor_loss      | 2.56e+03  |
# |    critic_loss     | 6.79e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4963      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 185       |
# |    ep_rew_mean     | -5.75e+04 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 90        |
# |    time_elapsed    | 65        |
# |    total_timesteps | 5908      |
# | train/             |           |
# |    actor_loss      | 2.94e+03  |
# |    critic_loss     | 2.21e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5807      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 169       |
# |    ep_rew_mean     | -5.24e+04 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 89        |
# |    time_elapsed    | 68        |
# |    total_timesteps | 6084      |
# | train/             |           |
# |    actor_loss      | 2.96e+03  |
# |    critic_loss     | 2.05e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5983      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 158       |
# |    ep_rew_mean     | -4.88e+04 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 87        |
# |    time_elapsed    | 72        |
# |    total_timesteps | 6333      |
# | train/             |           |
# |    actor_loss      | 3.07e+03  |
# |    critic_loss     | 3.38e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6232      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -4.6e+04 |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 86       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 6578     |
# | train/             |          |
# |    actor_loss      | 3.15e+03 |
# |    critic_loss     | 5.12e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6477     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 142       |
# |    ep_rew_mean     | -4.34e+04 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 85        |
# |    time_elapsed    | 79        |
# |    total_timesteps | 6806      |
# | train/             |           |
# |    actor_loss      | 3.17e+03  |
# |    critic_loss     | 7.79e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6705      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 134       |
# |    ep_rew_mean     | -4.11e+04 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 84        |
# |    time_elapsed    | 82        |
# |    total_timesteps | 6988      |
# | train/             |           |
# |    actor_loss      | 3.22e+03  |
# |    critic_loss     | 9.06e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6887      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 145       |
# |    ep_rew_mean     | -4.41e+04 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 85        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 8127      |
# | train/             |           |
# |    actor_loss      | 3.67e+03  |
# |    critic_loss     | 3e+05     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8026      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 141       |
# |    ep_rew_mean     | -4.27e+04 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 84        |
# |    time_elapsed    | 99        |
# |    total_timesteps | 8434      |
# | train/             |           |
# |    actor_loss      | 3.88e+03  |
# |    critic_loss     | 6.77e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8333      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 151       |
# |    ep_rew_mean     | -4.57e+04 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 87        |
# |    time_elapsed    | 110       |
# |    total_timesteps | 9690      |
# | train/             |           |
# |    actor_loss      | 4.37e+03  |
# |    critic_loss     | 1.55e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9589      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 146       |
# |    ep_rew_mean     | -4.42e+04 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 86        |
# |    time_elapsed    | 114       |
# |    total_timesteps | 9952      |
# | train/             |           |
# |    actor_loss      | 4.39e+03  |
# |    critic_loss     | 3.72e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9851      |
# ----------------------------------
# c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=-60968.17 +/- 52172.41
# Episode length: 204.30 +/- 181.07
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 204      |
# |    mean_reward     | -6.1e+04 |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 4.57e+03 |
# |    critic_loss     | 1.86e+05 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9899     |
# ---------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 142       |
# |    ep_rew_mean     | -4.27e+04 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 81        |
# |    time_elapsed    | 126       |
# |    total_timesteps | 10222     |
# | train/             |           |
# |    actor_loss      | 4.53e+03  |
# |    critic_loss     | 1.81e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10121     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 144       |
# |    ep_rew_mean     | -4.32e+04 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 81        |
# |    time_elapsed    | 134       |
# |    total_timesteps | 10918     |
# | train/             |           |
# |    actor_loss      | 4.85e+03  |
# |    critic_loss     | 5.04e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10817     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -4.2e+04 |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 80       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 11160    |
# | train/             |          |
# |    actor_loss      | 4.87e+03 |
# |    critic_loss     | 1.35e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11059    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 143       |
# |    ep_rew_mean     | -4.27e+04 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 81        |
# |    time_elapsed    | 147       |
# |    total_timesteps | 11998     |
# | train/             |           |
# |    actor_loss      | 5.2e+03   |
# |    critic_loss     | 4.88e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11897     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 140       |
# |    ep_rew_mean     | -4.19e+04 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 81        |
# |    time_elapsed    | 151       |
# |    total_timesteps | 12343     |
# | train/             |           |
# |    actor_loss      | 5.24e+03  |
# |    critic_loss     | 1.98e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12242     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 144       |
# |    ep_rew_mean     | -4.35e+04 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 82        |
# |    time_elapsed    | 160       |
# |    total_timesteps | 13246     |
# | train/             |           |
# |    actor_loss      | 5.87e+03  |
# |    critic_loss     | 2.55e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13145     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -4.8e+04 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 85       |
# |    time_elapsed    | 175      |
# |    total_timesteps | 15046    |
# | train/             |          |
# |    actor_loss      | 6.35e+03 |
# |    critic_loss     | 6.35e+05 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14945    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 152       |
# |    ep_rew_mean     | -4.65e+04 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 85        |
# |    time_elapsed    | 178       |
# |    total_timesteps | 15219     |
# | train/             |           |
# |    actor_loss      | 6.63e+03  |
# |    critic_loss     | 4.93e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15118     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | -4e+04   |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 84       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 15460    |
# | train/             |          |
# |    actor_loss      | 6.35e+03 |
# |    critic_loss     | 3.67e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15359    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 126       |
# |    ep_rew_mean     | -3.78e+04 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 84        |
# |    time_elapsed    | 187       |
# |    total_timesteps | 15843     |
# | train/             |           |
# |    actor_loss      | 6.56e+03  |
# |    critic_loss     | 3.9e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15742     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 127       |
# |    ep_rew_mean     | -3.79e+04 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 84        |
# |    time_elapsed    | 191       |
# |    total_timesteps | 16157     |
# | train/             |           |
# |    actor_loss      | 6.74e+03  |
# |    critic_loss     | 3.73e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16056     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 127       |
# |    ep_rew_mean     | -3.79e+04 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 83        |
# |    time_elapsed    | 196       |
# |    total_timesteps | 16508     |
# | train/             |           |
# |    actor_loss      | 6.71e+03  |
# |    critic_loss     | 1.78e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16407     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 125       |
# |    ep_rew_mean     | -3.72e+04 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 83        |
# |    time_elapsed    | 202       |
# |    total_timesteps | 16953     |
# | train/             |           |
# |    actor_loss      | 6.73e+03  |
# |    critic_loss     | 2.62e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16852     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 126       |
# |    ep_rew_mean     | -3.77e+04 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 83        |
# |    time_elapsed    | 208       |
# |    total_timesteps | 17481     |
# | train/             |           |
# |    actor_loss      | 7e+03     |
# |    critic_loss     | 1.48e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17380     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 130       |
# |    ep_rew_mean     | -3.88e+04 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 84        |
# |    time_elapsed    | 214       |
# |    total_timesteps | 18054     |
# | train/             |           |
# |    actor_loss      | 6.92e+03  |
# |    critic_loss     | 7.42e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17953     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 125       |
# |    ep_rew_mean     | -3.72e+04 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 83        |
# |    time_elapsed    | 218       |
# |    total_timesteps | 18374     |
# | train/             |           |
# |    actor_loss      | 7.19e+03  |
# |    critic_loss     | 1.06e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18273     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 126       |
# |    ep_rew_mean     | -3.79e+04 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 83        |
# |    time_elapsed    | 223       |
# |    total_timesteps | 18704     |
# | train/             |           |
# |    actor_loss      | 7.26e+03  |
# |    critic_loss     | 1.86e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18603     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 126       |
# |    ep_rew_mean     | -3.79e+04 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 83        |
# |    time_elapsed    | 227       |
# |    total_timesteps | 18968     |
# | train/             |           |
# |    actor_loss      | 7.55e+03  |
# |    critic_loss     | 6.67e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18867     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -3.8e+04 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 83       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 19248    |
# | train/             |          |
# |    actor_loss      | 7.53e+03 |
# |    critic_loss     | 3.8e+04  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19147    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 126       |
# |    ep_rew_mean     | -3.78e+04 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 82        |
# |    time_elapsed    | 235       |
# |    total_timesteps | 19438     |
# | train/             |           |
# |    actor_loss      | 7.24e+03  |
# |    critic_loss     | 4.1e+04   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19337     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 129       |
# |    ep_rew_mean     | -3.87e+04 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 82        |
# |    time_elapsed    | 240       |
# |    total_timesteps | 19935     |
# | train/             |           |
# |    actor_loss      | 7.15e+03  |
# |    critic_loss     | 6.82e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19834     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-82231.82 +/- 104459.33
# Episode length: 269.50 +/- 326.04
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 270       |
# |    mean_reward     | -8.22e+04 |
# | time/              |           |
# |    total_timesteps | 20000     |
# | train/             |           |
# |    actor_loss      | 7.75e+03  |
# |    critic_loss     | 2.59e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19899     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 132       |
# |    ep_rew_mean     | -4.04e+04 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 81        |
# |    time_elapsed    | 262       |
# |    total_timesteps | 21375     |
# | train/             |           |
# |    actor_loss      | 7.64e+03  |
# |    critic_loss     | 5.02e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21274     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 135       |
# |    ep_rew_mean     | -4.18e+04 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 81        |
# |    time_elapsed    | 269       |
# |    total_timesteps | 21948     |
# | train/             |           |
# |    actor_loss      | 7.93e+03  |
# |    critic_loss     | 1.78e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21847     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 128       |
# |    ep_rew_mean     | -3.96e+04 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 81        |
# |    time_elapsed    | 275       |
# |    total_timesteps | 22488     |
# | train/             |           |
# |    actor_loss      | 8e+03     |
# |    critic_loss     | 2.46e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22387     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 130       |
# |    ep_rew_mean     | -4.01e+04 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 81        |
# |    time_elapsed    | 280       |
# |    total_timesteps | 22907     |
# | train/             |           |
# |    actor_loss      | 7.99e+03  |
# |    critic_loss     | 5.04e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22806     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 130       |
# |    ep_rew_mean     | -4.01e+04 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 81        |
# |    time_elapsed    | 284       |
# |    total_timesteps | 23205     |
# | train/             |           |
# |    actor_loss      | 8.13e+03  |
# |    critic_loss     | 5.14e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23104     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 125       |
# |    ep_rew_mean     | -3.87e+04 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 81        |
# |    time_elapsed    | 288       |
# |    total_timesteps | 23460     |
# | train/             |           |
# |    actor_loss      | 8.21e+03  |
# |    critic_loss     | 2.25e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23359     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 130       |
# |    ep_rew_mean     | -4.01e+04 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 81        |
# |    time_elapsed    | 296       |
# |    total_timesteps | 24187     |
# | train/             |           |
# |    actor_loss      | 8.34e+03  |
# |    critic_loss     | 1.8e+06   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24086     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 124       |
# |    ep_rew_mean     | -3.84e+04 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 81        |
# |    time_elapsed    | 300       |
# |    total_timesteps | 24411     |
# | train/             |           |
# |    actor_loss      | 8.43e+03  |
# |    critic_loss     | 6.48e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24310     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -3.8e+04 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 81       |
# |    time_elapsed    | 303      |
# |    total_timesteps | 24631    |
# | train/             |          |
# |    actor_loss      | 8.13e+03 |
# |    critic_loss     | 2.69e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24530    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 117       |
# |    ep_rew_mean     | -3.58e+04 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 80        |
# |    time_elapsed    | 307       |
# |    total_timesteps | 24935     |
# | train/             |           |
# |    actor_loss      | 8.21e+03  |
# |    critic_loss     | 3.62e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24834     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -3.01e+04 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 80        |
# |    time_elapsed    | 311       |
# |    total_timesteps | 25121     |
# | train/             |           |
# |    actor_loss      | 8.48e+03  |
# |    critic_loss     | 7.57e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25020     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -3.05e+04 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 80        |
# |    time_elapsed    | 315       |
# |    total_timesteps | 25351     |
# | train/             |           |
# |    actor_loss      | 8.53e+03  |
# |    critic_loss     | 7.74e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25250     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -3.03e+04 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 80        |
# |    time_elapsed    | 318       |
# |    total_timesteps | 25534     |
# | train/             |           |
# |    actor_loss      | 8.37e+03  |
# |    critic_loss     | 5.13e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25433     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.8     |
# |    ep_rew_mean     | -3e+04   |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 79       |
# |    time_elapsed    | 321      |
# |    total_timesteps | 25722    |
# | train/             |          |
# |    actor_loss      | 8.45e+03 |
# |    critic_loss     | 8.98e+05 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25621    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 96.8      |
# |    ep_rew_mean     | -2.94e+04 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 79        |
# |    time_elapsed    | 324       |
# |    total_timesteps | 25839     |
# | train/             |           |
# |    actor_loss      | 8.48e+03  |
# |    critic_loss     | 4.03e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25738     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 97.1      |
# |    ep_rew_mean     | -2.91e+04 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 79        |
# |    time_elapsed    | 328       |
# |    total_timesteps | 26218     |
# | train/             |           |
# |    actor_loss      | 8.57e+03  |
# |    critic_loss     | 3.36e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26117     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 108       |
# |    ep_rew_mean     | -3.23e+04 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 80        |
# |    time_elapsed    | 343       |
# |    total_timesteps | 27727     |
# | train/             |           |
# |    actor_loss      | 8.9e+03   |
# |    critic_loss     | 2.83e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27626     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 109       |
# |    ep_rew_mean     | -3.24e+04 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 80        |
# |    time_elapsed    | 350       |
# |    total_timesteps | 28341     |
# | train/             |           |
# |    actor_loss      | 9.09e+03  |
# |    critic_loss     | 3.38e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28240     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 108       |
# |    ep_rew_mean     | -3.21e+04 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 81        |
# |    time_elapsed    | 355       |
# |    total_timesteps | 28832     |
# | train/             |           |
# |    actor_loss      | 8.86e+03  |
# |    critic_loss     | 6.22e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28731     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 109       |
# |    ep_rew_mean     | -3.25e+04 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 81        |
# |    time_elapsed    | 361       |
# |    total_timesteps | 29264     |
# | train/             |           |
# |    actor_loss      | 9.17e+03  |
# |    critic_loss     | 4.09e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29163     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 108       |
# |    ep_rew_mean     | -3.22e+04 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 80        |
# |    time_elapsed    | 365       |
# |    total_timesteps | 29544     |
# | train/             |           |
# |    actor_loss      | 8.98e+03  |
# |    critic_loss     | 8.64e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29443     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 109       |
# |    ep_rew_mean     | -3.23e+04 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 80        |
# |    time_elapsed    | 369       |
# |    total_timesteps | 29855     |
# | train/             |           |
# |    actor_loss      | 9.15e+03  |
# |    critic_loss     | 8.65e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29754     |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-18510.08 +/- 8760.79
# Episode length: 67.30 +/- 27.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 67.3      |
# |    mean_reward     | -1.85e+04 |
# | time/              |           |
# |    total_timesteps | 30000     |
# | train/             |           |
# |    actor_loss      | 8.98e+03  |
# |    critic_loss     | 1.93e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29899     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 109       |
# |    ep_rew_mean     | -3.23e+04 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 79        |
# |    time_elapsed    | 378       |
# |    total_timesteps | 30128     |
# | train/             |           |
# |    actor_loss      | 8.72e+03  |
# |    critic_loss     | 2.76e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30027     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 111       |
# |    ep_rew_mean     | -3.27e+04 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 79        |
# |    time_elapsed    | 382       |
# |    total_timesteps | 30505     |
# | train/             |           |
# |    actor_loss      | 9.2e+03   |
# |    critic_loss     | 5.22e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30404     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 112       |
# |    ep_rew_mean     | -3.32e+04 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 79        |
# |    time_elapsed    | 390       |
# |    total_timesteps | 31158     |
# | train/             |           |
# |    actor_loss      | 8.81e+03  |
# |    critic_loss     | 4.44e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31057     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 102       |
# |    ep_rew_mean     | -2.93e+04 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 79        |
# |    time_elapsed    | 395       |
# |    total_timesteps | 31602     |
# | train/             |           |
# |    actor_loss      | 9.2e+03   |
# |    critic_loss     | 3.75e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31501     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.1      |
# |    ep_rew_mean     | -2.78e+04 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 79        |
# |    time_elapsed    | 399       |
# |    total_timesteps | 31857     |
# | train/             |           |
# |    actor_loss      | 9.02e+03  |
# |    critic_loss     | 1.27e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31756     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 95.3      |
# |    ep_rew_mean     | -2.66e+04 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 79        |
# |    time_elapsed    | 402       |
# |    total_timesteps | 32021     |
# | train/             |           |
# |    actor_loss      | 9.27e+03  |
# |    critic_loss     | 2.05e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31920     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 94        |
# |    ep_rew_mean     | -2.63e+04 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 79        |
# |    time_elapsed    | 407       |
# |    total_timesteps | 32304     |
# | train/             |           |
# |    actor_loss      | 9.19e+03  |
# |    critic_loss     | 3.49e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32203     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 92.4      |
# |    ep_rew_mean     | -2.59e+04 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 79        |
# |    time_elapsed    | 409       |
# |    total_timesteps | 32443     |
# | train/             |           |
# |    actor_loss      | 9.22e+03  |
# |    critic_loss     | 1.35e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32342     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 92.3      |
# |    ep_rew_mean     | -2.59e+04 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 79        |
# |    time_elapsed    | 413       |
# |    total_timesteps | 32687     |
# | train/             |           |
# |    actor_loss      | 9.15e+03  |
# |    critic_loss     | 5.12e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32586     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.5      |
# |    ep_rew_mean     | -2.48e+04 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 79        |
# |    time_elapsed    | 417       |
# |    total_timesteps | 33033     |
# | train/             |           |
# |    actor_loss      | 9.56e+03  |
# |    critic_loss     | 8.24e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32932     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.3     |
# |    ep_rew_mean     | -2.5e+04 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 79       |
# |    time_elapsed    | 421      |
# |    total_timesteps | 33344    |
# | train/             |          |
# |    actor_loss      | 8.7e+03  |
# |    critic_loss     | 1.44e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 33243    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 89.5      |
# |    ep_rew_mean     | -2.52e+04 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 78        |
# |    time_elapsed    | 425       |
# |    total_timesteps | 33580     |
# | train/             |           |
# |    actor_loss      | 9.26e+03  |
# |    critic_loss     | 7.6e+04   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33479     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88        |
# |    ep_rew_mean     | -2.47e+04 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 78        |
# |    time_elapsed    | 428       |
# |    total_timesteps | 33737     |
# | train/             |           |
# |    actor_loss      | 9.69e+03  |
# |    critic_loss     | 4.43e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33636     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.2      |
# |    ep_rew_mean     | -2.48e+04 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 78        |
# |    time_elapsed    | 432       |
# |    total_timesteps | 33945     |
# | train/             |           |
# |    actor_loss      | 8.93e+03  |
# |    critic_loss     | 4.26e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33844     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.7      |
# |    ep_rew_mean     | -2.46e+04 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 78        |
# |    time_elapsed    | 436       |
# |    total_timesteps | 34219     |
# | train/             |           |
# |    actor_loss      | 9.18e+03  |
# |    critic_loss     | 5.89e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34118     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.5      |
# |    ep_rew_mean     | -2.46e+04 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 78        |
# |    time_elapsed    | 439       |
# |    total_timesteps | 34382     |
# | train/             |           |
# |    actor_loss      | 9.39e+03  |
# |    critic_loss     | 4.57e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34281     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88        |
# |    ep_rew_mean     | -2.44e+04 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 78        |
# |    time_elapsed    | 442       |
# |    total_timesteps | 34525     |
# | train/             |           |
# |    actor_loss      | 9.36e+03  |
# |    critic_loss     | 6.86e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34424     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 89.1      |
# |    ep_rew_mean     | -2.47e+04 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 77        |
# |    time_elapsed    | 445       |
# |    total_timesteps | 34747     |
# | train/             |           |
# |    actor_loss      | 9.27e+03  |
# |    critic_loss     | 1.18e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34646     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 87.1      |
# |    ep_rew_mean     | -2.43e+04 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 77        |
# |    time_elapsed    | 448       |
# |    total_timesteps | 34924     |
# | train/             |           |
# |    actor_loss      | 8.9e+03   |
# |    critic_loss     | 1.34e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34823     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 73.8      |
# |    ep_rew_mean     | -2.03e+04 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 77        |
# |    time_elapsed    | 451       |
# |    total_timesteps | 35106     |
# | train/             |           |
# |    actor_loss      | 9.58e+03  |
# |    critic_loss     | 2.19e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35005     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 68.8      |
# |    ep_rew_mean     | -1.89e+04 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 77        |
# |    time_elapsed    | 454       |
# |    total_timesteps | 35224     |
# | train/             |           |
# |    actor_loss      | 9.2e+03   |
# |    critic_loss     | 7.7e+04   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35123     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.9     |
# |    ep_rew_mean     | -1.8e+04 |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 77       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 35419    |
# | train/             |          |
# |    actor_loss      | 9.24e+03 |
# |    critic_loss     | 5.61e+05 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35318    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.5      |
# |    ep_rew_mean     | -1.75e+04 |
# | time/              |           |
# |    episodes        | 332       |
# |    fps             | 77        |
# |    time_elapsed    | 462       |
# |    total_timesteps | 35709     |
# | train/             |           |
# |    actor_loss      | 1.01e+04  |
# |    critic_loss     | 3.74e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35608     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 62.9      |
# |    ep_rew_mean     | -1.72e+04 |
# | time/              |           |
# |    episodes        | 336       |
# |    fps             | 77        |
# |    time_elapsed    | 464       |
# |    total_timesteps | 35835     |
# | train/             |           |
# |    actor_loss      | 9.26e+03  |
# |    critic_loss     | 2.34e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35734     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 61.5      |
# |    ep_rew_mean     | -1.68e+04 |
# | time/              |           |
# |    episodes        | 340       |
# |    fps             | 76        |
# |    time_elapsed    | 468       |
# |    total_timesteps | 36004     |
# | train/             |           |
# |    actor_loss      | 9.77e+03  |
# |    critic_loss     | 6.92e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35903     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 61.1      |
# |    ep_rew_mean     | -1.68e+04 |
# | time/              |           |
# |    episodes        | 344       |
# |    fps             | 76        |
# |    time_elapsed    | 471       |
# |    total_timesteps | 36237     |
# | train/             |           |
# |    actor_loss      | 9.39e+03  |
# |    critic_loss     | 5.74e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36136     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 59.1      |
# |    ep_rew_mean     | -1.65e+04 |
# | time/              |           |
# |    episodes        | 348       |
# |    fps             | 76        |
# |    time_elapsed    | 475       |
# |    total_timesteps | 36417     |
# | train/             |           |
# |    actor_loss      | 9.01e+03  |
# |    critic_loss     | 1.29e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36316     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.2     |
# |    ep_rew_mean     | -1.5e+04 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 76       |
# |    time_elapsed    | 478      |
# |    total_timesteps | 36576    |
# | train/             |          |
# |    actor_loss      | 9.21e+03 |
# |    critic_loss     | 3.77e+05 |
# |    learning_rate   | 0.001    |
# ...
# |    critic_loss     | 2.19e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 96917     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.8      |
# |    ep_rew_mean     | -7.97e+03 |
# | time/              |           |
# |    episodes        | 1868      |
# |    fps             | 62        |
# |    time_elapsed    | 1549      |
# |    total_timesteps | 97138     |
# | train/             |           |
# |    actor_loss      | 4.21e+03  |
# |    critic_loss     | 1.72e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97037     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 28.2      |
# |    ep_rew_mean     | -8.04e+03 |
# | time/              |           |
# |    episodes        | 1872      |
# |    fps             | 62        |
# |    time_elapsed    | 1551      |
# |    total_timesteps | 97247     |
# | train/             |           |
# |    actor_loss      | 4.38e+03  |
# |    critic_loss     | 1.09e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97146     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -7.86e+03 |
# | time/              |           |
# |    episodes        | 1876      |
# |    fps             | 62        |
# |    time_elapsed    | 1553      |
# |    total_timesteps | 97309     |
# | train/             |           |
# |    actor_loss      | 3.94e+03  |
# |    critic_loss     | 8.47e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97208     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.2      |
# |    ep_rew_mean     | -7.79e+03 |
# | time/              |           |
# |    episodes        | 1880      |
# |    fps             | 62        |
# |    time_elapsed    | 1555      |
# |    total_timesteps | 97415     |
# | train/             |           |
# |    actor_loss      | 3.9e+03   |
# |    critic_loss     | 1.2e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97314     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.2      |
# |    ep_rew_mean     | -7.79e+03 |
# | time/              |           |
# |    episodes        | 1884      |
# |    fps             | 62        |
# |    time_elapsed    | 1558      |
# |    total_timesteps | 97538     |
# | train/             |           |
# |    actor_loss      | 4e+03     |
# |    critic_loss     | 1.42e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97437     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 26.7      |
# |    ep_rew_mean     | -7.64e+03 |
# | time/              |           |
# |    episodes        | 1888      |
# |    fps             | 62        |
# |    time_elapsed    | 1560      |
# |    total_timesteps | 97591     |
# | train/             |           |
# |    actor_loss      | 4.33e+03  |
# |    critic_loss     | 7.95e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97490     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 26.3      |
# |    ep_rew_mean     | -7.56e+03 |
# | time/              |           |
# |    episodes        | 1892      |
# |    fps             | 62        |
# |    time_elapsed    | 1562      |
# |    total_timesteps | 97665     |
# | train/             |           |
# |    actor_loss      | 4.39e+03  |
# |    critic_loss     | 1.03e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97564     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.2      |
# |    ep_rew_mean     | -7.83e+03 |
# | time/              |           |
# |    episodes        | 1896      |
# |    fps             | 62        |
# |    time_elapsed    | 1565      |
# |    total_timesteps | 97849     |
# | train/             |           |
# |    actor_loss      | 4.03e+03  |
# |    critic_loss     | 1e+05     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97748     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -7.86e+03 |
# | time/              |           |
# |    episodes        | 1900      |
# |    fps             | 62        |
# |    time_elapsed    | 1567      |
# |    total_timesteps | 97938     |
# | train/             |           |
# |    actor_loss      | 3.81e+03  |
# |    critic_loss     | 7.51e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97837     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.1      |
# |    ep_rew_mean     | -7.77e+03 |
# | time/              |           |
# |    episodes        | 1904      |
# |    fps             | 62        |
# |    time_elapsed    | 1569      |
# |    total_timesteps | 98016     |
# | train/             |           |
# |    actor_loss      | 4.03e+03  |
# |    critic_loss     | 7.19e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 97915     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -7.93e+03 |
# | time/              |           |
# |    episodes        | 1908      |
# |    fps             | 62        |
# |    time_elapsed    | 1572      |
# |    total_timesteps | 98156     |
# | train/             |           |
# |    actor_loss      | 4.18e+03  |
# |    critic_loss     | 1.76e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98055     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -7.83e+03 |
# | time/              |           |
# |    episodes        | 1912      |
# |    fps             | 62        |
# |    time_elapsed    | 1574      |
# |    total_timesteps | 98262     |
# | train/             |           |
# |    actor_loss      | 3.71e+03  |
# |    critic_loss     | 1.2e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98161     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.7      |
# |    ep_rew_mean     | -7.92e+03 |
# | time/              |           |
# |    episodes        | 1916      |
# |    fps             | 62        |
# |    time_elapsed    | 1576      |
# |    total_timesteps | 98415     |
# | train/             |           |
# |    actor_loss      | 4.39e+03  |
# |    critic_loss     | 7.73e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98314     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 28.5      |
# |    ep_rew_mean     | -8.16e+03 |
# | time/              |           |
# |    episodes        | 1920      |
# |    fps             | 62        |
# |    time_elapsed    | 1579      |
# |    total_timesteps | 98590     |
# | train/             |           |
# |    actor_loss      | 4.27e+03  |
# |    critic_loss     | 9.81e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98489     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.9      |
# |    ep_rew_mean     | -7.94e+03 |
# | time/              |           |
# |    episodes        | 1924      |
# |    fps             | 62        |
# |    time_elapsed    | 1581      |
# |    total_timesteps | 98673     |
# | train/             |           |
# |    actor_loss      | 4.44e+03  |
# |    critic_loss     | 6.97e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98572     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 28.1      |
# |    ep_rew_mean     | -8.01e+03 |
# | time/              |           |
# |    episodes        | 1928      |
# |    fps             | 62        |
# |    time_elapsed    | 1584      |
# |    total_timesteps | 98758     |
# | train/             |           |
# |    actor_loss      | 4.17e+03  |
# |    critic_loss     | 9.49e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98657     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 28        |
# |    ep_rew_mean     | -7.96e+03 |
# | time/              |           |
# |    episodes        | 1932      |
# |    fps             | 62        |
# |    time_elapsed    | 1586      |
# |    total_timesteps | 98839     |
# | train/             |           |
# |    actor_loss      | 4.05e+03  |
# |    critic_loss     | 2.34e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98738     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.7      |
# |    ep_rew_mean     | -7.89e+03 |
# | time/              |           |
# |    episodes        | 1936      |
# |    fps             | 62        |
# |    time_elapsed    | 1588      |
# |    total_timesteps | 98931     |
# | train/             |           |
# |    actor_loss      | 4.36e+03  |
# |    critic_loss     | 1.2e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98830     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -7.81e+03 |
# | time/              |           |
# |    episodes        | 1940      |
# |    fps             | 62        |
# |    time_elapsed    | 1590      |
# |    total_timesteps | 99007     |
# | train/             |           |
# |    actor_loss      | 3.97e+03  |
# |    critic_loss     | 1.31e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98906     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.9      |
# |    ep_rew_mean     | -7.91e+03 |
# | time/              |           |
# |    episodes        | 1944      |
# |    fps             | 62        |
# |    time_elapsed    | 1592      |
# |    total_timesteps | 99097     |
# | train/             |           |
# |    actor_loss      | 3.98e+03  |
# |    critic_loss     | 1.36e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 98996     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.8      |
# |    ep_rew_mean     | -7.84e+03 |
# | time/              |           |
# |    episodes        | 1948      |
# |    fps             | 62        |
# |    time_elapsed    | 1594      |
# |    total_timesteps | 99167     |
# | train/             |           |
# |    actor_loss      | 4.32e+03  |
# |    critic_loss     | 1.03e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99066     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -7.65e+03 |
# | time/              |           |
# |    episodes        | 1952      |
# |    fps             | 62        |
# |    time_elapsed    | 1596      |
# |    total_timesteps | 99219     |
# | train/             |           |
# |    actor_loss      | 4.21e+03  |
# |    critic_loss     | 5.08e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99118     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.2      |
# |    ep_rew_mean     | -7.63e+03 |
# | time/              |           |
# |    episodes        | 1956      |
# |    fps             | 62        |
# |    time_elapsed    | 1598      |
# |    total_timesteps | 99327     |
# | train/             |           |
# |    actor_loss      | 4.31e+03  |
# |    critic_loss     | 8.17e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99226     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 26.3      |
# |    ep_rew_mean     | -7.31e+03 |
# | time/              |           |
# |    episodes        | 1960      |
# |    fps             | 62        |
# |    time_elapsed    | 1601      |
# |    total_timesteps | 99424     |
# | train/             |           |
# |    actor_loss      | 4.15e+03  |
# |    critic_loss     | 7.78e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99323     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24.9      |
# |    ep_rew_mean     | -6.82e+03 |
# | time/              |           |
# |    episodes        | 1964      |
# |    fps             | 62        |
# |    time_elapsed    | 1603      |
# |    total_timesteps | 99512     |
# | train/             |           |
# |    actor_loss      | 4.41e+03  |
# |    critic_loss     | 1.97e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99411     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24.4      |
# |    ep_rew_mean     | -6.74e+03 |
# | time/              |           |
# |    episodes        | 1968      |
# |    fps             | 62        |
# |    time_elapsed    | 1605      |
# |    total_timesteps | 99579     |
# | train/             |           |
# |    actor_loss      | 4.23e+03  |
# |    critic_loss     | 7.16e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99478     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24.5      |
# |    ep_rew_mean     | -6.81e+03 |
# | time/              |           |
# |    episodes        | 1972      |
# |    fps             | 62        |
# |    time_elapsed    | 1607      |
# |    total_timesteps | 99696     |
# | train/             |           |
# |    actor_loss      | 4.45e+03  |
# |    critic_loss     | 2.49e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99595     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24.9      |
# |    ep_rew_mean     | -6.92e+03 |
# | time/              |           |
# |    episodes        | 1976      |
# |    fps             | 61        |
# |    time_elapsed    | 1609      |
# |    total_timesteps | 99798     |
# | train/             |           |
# |    actor_loss      | 4.03e+03  |
# |    critic_loss     | 8.08e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99697     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24.6      |
# |    ep_rew_mean     | -6.88e+03 |
# | time/              |           |
# |    episodes        | 1980      |
# |    fps             | 61        |
# |    time_elapsed    | 1612      |
# |    total_timesteps | 99879     |
# | train/             |           |
# |    actor_loss      | 3.84e+03  |
# |    critic_loss     | 1.04e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99778     |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-5193.82 +/- 3021.02
# Episode length: 19.10 +/- 10.97
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 19.1      |
# |    mean_reward     | -5.19e+03 |
# | time/              |           |
# |    total_timesteps | 100000    |
# | train/             |           |
# |    actor_loss      | 4.01e+03  |
# |    critic_loss     | 1.26e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 99899     |
# ----------------------------------
# New best mean reward!
# Training is finished
# Mean Reward over 10 episodes: -8809.51 +/- 3584.27

# %%
import gymnasium as gym
import time
from LunarLander3DEnv.envs import LunarLander3DEnv
# Pilih algoritma yang digunakan saat training, misal "PPO"

algorithm = "TD3"
model_path = f"ll3d_{algorithm}"  # Nama file model yang telah disimpan

# Buat environment dengan render_mode "human" agar dapat melihat visualisasi
env = gym.make("LunarLander3DEnv-v0", render_mode="human")

# Muat model berdasarkan algoritma yang dipilih
if algorithm == "PPO":
    from stable_baselines3 import PPO
    model = PPO.load(model_path, env=env)
elif algorithm == "A2C":
    from stable_baselines3 import A2C
    model = A2C.load(model_path, env=env)
elif algorithm == "DDPG":
    from stable_baselines3 import DDPG
    model = DDPG.load(model_path, env=env)
elif algorithm == "SAC":
    from stable_baselines3 import SAC
    model = SAC.load(model_path, env=env)
elif algorithm == "TD3":
    from stable_baselines3 import TD3
    model = TD3.load(model_path, env=env)
elif algorithm == "TRPO":
    from sb3_contrib import TRPO
    model = TRPO.load(model_path, env=env)
else:
    raise ValueError("Algoritma yang dipilih tidak didukung.")

# Jalankan beberapa episode untuk inferensi
num_episodes = 10
for episode in range(1, num_episodes+1):
    obs, info = env.reset()
    done = False
    total_reward = 0.0
    while not done:
        # Prediksi aksi dengan deterministik
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        env.render()  # Pastikan render dipanggil agar kamera dan visualisasi diupdate
        time.sleep(1/60)  # Optional: delay untuk melambatkan tampilan
        done = terminated or truncated
    print(f"Episode {episode}: Total Reward = {total_reward:.2f}")

env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1: Total Reward = -22356.72
# Episode 2: Total Reward = -312429.88
# Episode 3: Total Reward = -20599.19
# Episode 4: Total Reward = -61393.19
# Episode 5: Total Reward = -16824.18
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 43
#      40 while not done:
#      41     # Prediksi aksi dengan deterministik
#      42     action, _ = model.predict(obs, deterministic=True)
# ---> 43     obs, reward, terminated, truncated, info = env.step(action)
#      44     total_reward += reward
#      45     env.render()  # Pastikan render dipanggil agar kamera dan visualisasi diupdate
#
# File c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\User\Documents\DATA\Fitra Nurmayadi\TWSBR\twsbr\LunarLander3DEnv\envs\LunarLander3DEnv.py:220, in LunarLander3DEnv.step(self, action)
#     218 def step(self, action):
#     219     action = np.clip(action, self.action_space.low, self.action_space.high)
# --> 220     self._apply_thruster_forces(action)
#     221     self._apply_dynamics()
#     222     self._bullet_client.stepSimulation()
#
# File c:\Users\User\Documents\DATA\Fitra Nurmayadi\TWSBR\twsbr\LunarLander3DEnv\envs\LunarLander3DEnv.py:241, in LunarLander3DEnv._apply_thruster_forces(self, action)
#     240 def _apply_thruster_forces(self, action):
# --> 241     base_pos, base_orient = self._bullet_client.getBasePositionAndOrientation(self.lander_id)
#     242     rot_matrix = np.array(self._bullet_client.getMatrixFromQuaternion(base_orient)).reshape(3, 3)
#     244     # Main thruster (action index 0)
#
# error: Not connected to physics server.
