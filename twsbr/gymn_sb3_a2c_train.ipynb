# %% [markdown]
# #Environment Check

# %%
import gymnasium as gym
import torch as th
import numpy as np
from twsbr_env.envs import TwsbrEnv  # Import environment
from stable_baselines3 import SAC, A2C, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, BaseCallback
from stable_baselines3.common.logger import configure

# Buat environment
env = gym.make("TwsbrEnv-v0", render_mode=None, action_type="continuous")

# Fungsi untuk scheduling learning rate
def lr_schedule(progress):
    return 1e-4 + (1e-3 - 1e-4) * (1 - np.cos(np.pi * progress)) / 2

# Callback untuk mengupdate ent_coef selama training
class EntropyScheduleCallback(BaseCallback):
    def __init__(self, start_ent=0.05, end_ent=0.001, total_timesteps=1e5, verbose=0):
        super().__init__(verbose)
        self.start_ent = start_ent
        self.end_ent = end_ent
        self.total_timesteps = total_timesteps

    def _on_step(self) -> bool:
        progress = self.num_timesteps / self.total_timesteps
        if progress < 0.1:
            self.model.ent_coef = 0.2
        elif progress < 0.25:
            self.model.ent_coef = 0.1
        elif progress < 0.5:
            self.model.ent_coef = 0.05
        else:
            self.model.ent_coef = 0.001
        return True

# Pilih Algoritma (SAC, A2C, PPO)
algorithm = "A2C"  # Pilihan: "SAC", "PPO", "A2C"

if algorithm == "PPO":
    model = PPO(
        "MlpPolicy", env,
        n_steps=2048, batch_size=128, n_epochs=10,
        target_kl=0.05,
        ent_coef=0.1,
       
        verbose=1,
    )
elif algorithm == "A2C":
    model = A2C(
        "MlpPolicy", env,
        ent_coef=0.1,
       
        verbose=1,
    )
else:  # Default ke SAC
    model = SAC(
        "MlpPolicy", env,
        buffer_size=int(1e6),
       
        use_sde=True, ent_coef="auto_0.1",
        verbose=1,
    )

# Setup TensorBoard logger
#log_dir = "./tensorboard_logs/"
#logger = configure(log_dir, ['tensorboard'])
#model.set_logger(logger)

# Setup callbacks
total_timesteps_learning = 1_000_000
save_freq_learning = total_timesteps_learning / 10
checkpoint_callback = CheckpointCallback(save_freq=save_freq_learning, save_path='./models/', name_prefix=f'{algorithm.lower()}_checkpoint')
eval_callback = EvalCallback(env, best_model_save_path="./logs/", log_path="./logs/", eval_freq=save_freq_learning, n_eval_episodes=5, deterministic=True)
entropy_callback = EntropyScheduleCallback(start_ent=0.1, end_ent=0.001, total_timesteps=total_timesteps_learning)

# Training model
model.learn(total_timesteps=total_timesteps_learning, callback=[checkpoint_callback, eval_callback, entropy_callback])

# Simpan model
model.save("twsbr_a2c")
print("Training is finished")

# Evaluasi model
n_eval_episodes = 10
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=n_eval_episodes, render=False)
print(f"Mean Reward over {n_eval_episodes} episodes: {mean_reward:.2f} +/- {std_reward:.2f}")

env.close()
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.2     |
# |    ep_rew_mean        | -25.8    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 7        |
# |    iterations         | 100      |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | -2.47    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -1.62    |
# |    std                | 1.07     |
# |    value_loss         | 0.353    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.6     |
# |    ep_rew_mean        | -25.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 7        |
# |    iterations         | 200      |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | -0.0906  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -20.3    |
# |    std                | 1.1      |
# |    value_loss         | 138      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.2     |
# |    ep_rew_mean        | -25.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 7        |
# |    iterations         | 300      |
# |    time_elapsed       | 200      |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | -0.00349 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -15.5    |
# |    std                | 1.13     |
# |    value_loss         | 104      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.2     |
# |    ep_rew_mean        | -25.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 7        |
# |    iterations         | 400      |
# |    time_elapsed       | 265      |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | -0.0474  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -49.9    |
# |    std                | 1.16     |
# |    value_loss         | 205      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 11.6     |
# |    ep_rew_mean        | -25.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 7        |
# |    iterations         | 500      |
# |    time_elapsed       | 316      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -3.22    |
# |    explained_variance | 0.55     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.907    |
# |    std                | 1.21     |
# |    value_loss         | 0.0363   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.8     |
# |    ep_rew_mean        | -25.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 8        |
# |    iterations         | 600      |
# |    time_elapsed       | 369      |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -3.3     |
# |    explained_variance | -1.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -1.31    |
# |    std                | 1.26     |
# |    value_loss         | 0.169    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.7     |
# |    ep_rew_mean        | -25.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 8        |
# |    iterations         | 700      |
# |    time_elapsed       | 417      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -3.37    |
# |    explained_variance | -20.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.69     |
# |    std                | 1.31     |
# |    value_loss         | 0.362    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.8     |
# |    ep_rew_mean        | -25.9    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 8        |
# |    iterations         | 800      |
# |    time_elapsed       | 466      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.45    |
# |    explained_variance | 0.079    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.823    |
# |    std                | 1.36     |
# |    value_loss         | 0.0605   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.3     |
# |    ep_rew_mean        | -26.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 8        |
# |    iterations         | 900      |
# |    time_elapsed       | 508      |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.53    |
# |    explained_variance | -1.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.354    |
# |    std                | 1.42     |
# |    value_loss         | 0.0336   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.1     |
# |    ep_rew_mean        | -26      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 9        |
# |    iterations         | 1000     |
# |    time_elapsed       | 550      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.61    |
# |    explained_variance | -2.32    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0656  |
# |    std                | 1.48     |
# |    value_loss         | 0.00207  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.7     |
# |    ep_rew_mean        | -26.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 9        |
# |    iterations         | 1100     |
# |    time_elapsed       | 591      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -3.71    |
# |    explained_variance | -0.936   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -77.1    |
# |    std                | 1.55     |
# |    value_loss         | 371      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.6     |
# |    ep_rew_mean        | -26.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 9        |
# |    iterations         | 1200     |
# |    time_elapsed       | 622      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.84    |
# |    explained_variance | -0.0206  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -64.5    |
# |    std                | 1.65     |
# |    value_loss         | 388      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.2     |
# |    ep_rew_mean        | -26.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 9        |
# |    iterations         | 1300     |
# |    time_elapsed       | 663      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -3.94    |
# |    explained_variance | -15      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.972    |
# |    std                | 1.74     |
# |    value_loss         | 0.121    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.9     |
# |    ep_rew_mean        | -26.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1400     |
# |    time_elapsed       | 699      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -4.05    |
# |    explained_variance | -1.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.501    |
# |    std                | 1.83     |
# |    value_loss         | 0.0263   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.7     |
# |    ep_rew_mean        | -26.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1500     |
# |    time_elapsed       | 736      |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -4.15    |
# |    explained_variance | -3.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.103    |
# |    std                | 1.93     |
# |    value_loss         | 0.013    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.1     |
# |    ep_rew_mean        | -26.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1600     |
# |    time_elapsed       | 771      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.25    |
# |    explained_variance | -3.79    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.988    |
# |    std                | 2.03     |
# |    value_loss         | 0.0725   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | -26.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1700     |
# |    time_elapsed       | 806      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -4.34    |
# |    explained_variance | -0.0249  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -67.5    |
# |    std                | 2.12     |
# |    value_loss         | 330      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.8     |
# |    ep_rew_mean        | -26.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1800     |
# |    time_elapsed       | 844      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -4.43    |
# |    explained_variance | 0.745    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.941   |
# |    std                | 2.21     |
# |    value_loss         | 0.0387   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.2     |
# |    ep_rew_mean        | -26.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 1900     |
# |    time_elapsed       | 884      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -4.52    |
# |    explained_variance | -0.0949  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.89    |
# |    std                | 2.32     |
# |    value_loss         | 0.122    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.3     |
# |    ep_rew_mean        | -26.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 2000     |
# |    time_elapsed       | 923      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.62    |
# |    explained_variance | -6.07    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.768    |
# |    std                | 2.44     |
# |    value_loss         | 0.0502   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.4     |
# |    ep_rew_mean        | -26.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 2100     |
# |    time_elapsed       | 955      |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -4.73    |
# |    explained_variance | 0.349    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -1.95    |
# |    std                | 2.57     |
# |    value_loss         | 0.164    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.8     |
# |    ep_rew_mean        | -26.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2200     |
# |    time_elapsed       | 996      |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -4.82    |
# |    explained_variance | -0.0167  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -52      |
# |    std                | 2.7      |
# |    value_loss         | 246      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.4     |
# |    ep_rew_mean        | -26.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2300     |
# |    time_elapsed       | 1036     |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -4.92    |
# |    explained_variance | -1.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.351    |
# |    std                | 2.84     |
# |    value_loss         | 0.0142   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23       |
# |    ep_rew_mean        | -26.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2400     |
# |    time_elapsed       | 1070     |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -5.03    |
# |    explained_variance | -4.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 1.01     |
# |    std                | 2.99     |
# |    value_loss         | 0.0585   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.1     |
# |    ep_rew_mean        | -26.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2500     |
# |    time_elapsed       | 1110     |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -5.12    |
# |    explained_variance | 0.146    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -1.38    |
# |    std                | 3.14     |
# |    value_loss         | 0.108    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.5     |
# |    ep_rew_mean        | -26.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2600     |
# |    time_elapsed       | 1149     |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -5.21    |
# |    explained_variance | -0.0296  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -79.1    |
# |    std                | 3.28     |
# |    value_loss         | 347      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | -27      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2700     |
# |    time_elapsed       | 1177     |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -5.31    |
# |    explained_variance | 0.0446   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -91.2    |
# |    std                | 3.44     |
# |    value_loss         | 337      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.4     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2800     |
# |    time_elapsed       | 1210     |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -5.41    |
# |    explained_variance | -0.839   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.414    |
# |    std                | 3.63     |
# |    value_loss         | 0.00856  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.2     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 2900     |
# |    time_elapsed       | 1243     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -5.5     |
# |    explained_variance | -0.219   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -2.07    |
# |    std                | 3.79     |
# |    value_loss         | 0.312    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.2     |
# |    ep_rew_mean        | -27.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3000     |
# |    time_elapsed       | 1275     |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -5.6     |
# |    explained_variance | -2.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.61     |
# |    std                | 3.98     |
# |    value_loss         | 0.0922   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.6     |
# |    ep_rew_mean        | -27.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3100     |
# |    time_elapsed       | 1312     |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -5.69    |
# |    explained_variance | 0.0281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -66.7    |
# |    std                | 4.16     |
# |    value_loss         | 217      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | -27.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3200     |
# |    time_elapsed       | 1349     |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | -7.89    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -1.86    |
# |    std                | 4.34     |
# |    value_loss         | 0.165    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.2     |
# |    ep_rew_mean        | -27.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3300     |
# |    time_elapsed       | 1380     |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | -1.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.111    |
# |    std                | 4.54     |
# |    value_loss         | 0.00225  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.2     |
# |    ep_rew_mean        | -27.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3400     |
# |    time_elapsed       | 1415     |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -5.96    |
# |    explained_variance | -0.0224  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -85.2    |
# |    std                | 4.77     |
# |    value_loss         | 280      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3500     |
# |    time_elapsed       | 1447     |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -6.07    |
# |    explained_variance | 0.43     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.72     |
# |    std                | 5.02     |
# |    value_loss         | 0.016    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.7     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3600     |
# |    time_elapsed       | 1481     |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -6.17    |
# |    explained_variance | -4.6     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.327    |
# |    std                | 5.3      |
# |    value_loss         | 0.0163   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.2     |
# |    ep_rew_mean        | -27.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3700     |
# |    time_elapsed       | 1515     |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -6.26    |
# |    explained_variance | 0.604    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.213    |
# |    std                | 5.54     |
# |    value_loss         | 0.00323  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.8     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3800     |
# |    time_elapsed       | 1551     |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -6.37    |
# |    explained_variance | 0.338    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.806    |
# |    std                | 5.85     |
# |    value_loss         | 0.0179   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.5     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3900     |
# |    time_elapsed       | 1584     |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -6.47    |
# |    explained_variance | -1.08    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.326    |
# |    std                | 6.16     |
# |    value_loss         | 0.00644  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.7     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4000     |
# |    time_elapsed       | 1616     |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -6.58    |
# |    explained_variance | 0.0292   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 1.34     |
# |    std                | 6.5      |
# |    value_loss         | 0.0485   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | -27.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4100     |
# |    time_elapsed       | 1647     |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -6.68    |
# |    explained_variance | 0.743    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.206   |
# |    std                | 6.83     |
# |    value_loss         | 0.00274  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.8     |
# |    ep_rew_mean        | -27.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4200     |
# |    time_elapsed       | 1680     |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -6.77    |
# |    explained_variance | -10.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 1.19     |
# |    std                | 7.13     |
# |    value_loss         | 0.0892   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.7     |
# |    ep_rew_mean        | -27.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4300     |
# |    time_elapsed       | 1714     |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -6.87    |
# |    explained_variance | -0.531   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.924    |
# |    std                | 7.53     |
# |    value_loss         | 0.0254   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.3     |
# |    ep_rew_mean        | -27.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4400     |
# |    time_elapsed       | 1743     |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -6.99    |
# |    explained_variance | -0.0108  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -36.5    |
# |    std                | 7.96     |
# |    value_loss         | 93.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.6     |
# |    ep_rew_mean        | -27.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4500     |
# |    time_elapsed       | 1776     |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -7.09    |
# |    explained_variance | -1.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -1.56    |
# |    std                | 8.39     |
# |    value_loss         | 0.0604   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.5     |
# |    ep_rew_mean        | -27.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4600     |
# |    time_elapsed       | 1804     |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -7.19    |
# |    explained_variance | -2.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.312   |
# |    std                | 8.83     |
# |    value_loss         | 0.00315  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.6     |
# |    ep_rew_mean        | -27.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4700     |
# |    time_elapsed       | 1833     |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -7.31    |
# |    explained_variance | 0.521    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.874    |
# |    std                | 9.36     |
# |    value_loss         | 0.0173   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.5     |
# |    ep_rew_mean        | -27.5    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4800     |
# |    time_elapsed       | 1866     |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -7.41    |
# |    explained_variance | -5.66    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.316   |
# |    std                | 9.87     |
# |    value_loss         | 0.0139   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -27.7    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 4900     |
# |    time_elapsed       | 1897     |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -7.51    |
# |    explained_variance | 0.0419   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.265    |
# |    std                | 10.4     |
# |    value_loss         | 0.00506  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.1     |
# |    ep_rew_mean        | -27.6    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 5000     |
# |    time_elapsed       | 1937     |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -7.6     |
# |    explained_variance | 0.0395   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.257    |
# |    std                | 10.9     |
# |    value_loss         | 0.00266  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26       |
# |    ep_rew_mean        | -27.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 5100     |
# |    time_elapsed       | 1973     |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -7.7     |
# |    explained_variance | -1.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.243   |
# |    std                | 11.4     |
# |    value_loss         | 0.00876  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.3     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 5200     |
# |    time_elapsed       | 2007     |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -7.79    |
# |    explained_variance | 0.0281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.465   |
# |    std                | 11.9     |
# |    value_loss         | 0.0287   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.9     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 5300     |
# |    time_elapsed       | 2039     |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -7.9     |
# |    explained_variance | -1.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.699    |
# |    std                | 12.6     |
# |    value_loss         | 0.0111   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.6     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5400     |
# |    time_elapsed       | 2072     |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -7.99    |
# |    explained_variance | 0.0125   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -28.3    |
# |    std                | 13.2     |
# |    value_loss         | 74.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.6     |
# |    ep_rew_mean        | -27.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5500     |
# |    time_elapsed       | 2104     |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -8.09    |
# |    explained_variance | -1.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 1.09     |
# |    std                | 13.9     |
# |    value_loss         | 0.0325   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.8     |
# |    ep_rew_mean        | -27.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5600     |
# |    time_elapsed       | 2140     |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -8.19    |
# |    explained_variance | -0.0482  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.623    |
# |    std                | 14.5     |
# |    value_loss         | 0.009    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.5     |
# |    ep_rew_mean        | -27      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5700     |
# |    time_elapsed       | 2180     |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -8.29    |
# |    explained_variance | 0.00839  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.761    |
# |    std                | 15.3     |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.1     |
# |    ep_rew_mean        | -26.9    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5800     |
# |    time_elapsed       | 2211     |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -8.39    |
# |    explained_variance | -0.00155 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -106     |
# |    std                | 16.1     |
# |    value_loss         | 255      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.6     |
# |    ep_rew_mean        | -26.8    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 5900     |
# |    time_elapsed       | 2243     |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -8.5     |
# |    explained_variance | -1.34    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -1.24    |
# |    std                | 16.9     |
# |    value_loss         | 0.0243   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.6     |
# |    ep_rew_mean        | -26.9    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6000     |
# |    time_elapsed       | 2271     |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -8.59    |
# |    explained_variance | -0.83    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.72     |
# |    std                | 17.8     |
# |    value_loss         | 0.0351   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.3     |
# |    ep_rew_mean        | -27      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6100     |
# |    time_elapsed       | 2304     |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -8.7     |
# |    explained_variance | -0.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -3.06    |
# |    std                | 18.8     |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.6     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6200     |
# |    time_elapsed       | 2336     |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -8.8     |
# |    explained_variance | -0.444   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.45     |
# |    std                | 19.8     |
# |    value_loss         | 0.00976  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28       |
# |    ep_rew_mean        | -27.4    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6300     |
# |    time_elapsed       | 2372     |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -8.9     |
# |    explained_variance | 0.493    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.898    |
# |    std                | 20.7     |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.4     |
# |    ep_rew_mean        | -27.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6400     |
# |    time_elapsed       | 2411     |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -9       |
# |    explained_variance | -0.293   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -189     |
# |    std                | 21.8     |
# |    value_loss         | 465      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.7     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6500     |
# |    time_elapsed       | 2443     |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -9.11    |
# |    explained_variance | -0.205   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.497   |
# |    std                | 23       |
# |    value_loss         | 0.00703  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.8     |
# |    ep_rew_mean        | -27.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6600     |
# |    time_elapsed       | 2475     |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -9.22    |
# |    explained_variance | -0.747   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.35     |
# |    std                | 24.4     |
# |    value_loss         | 0.00647  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.1     |
# |    ep_rew_mean        | -26.9    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 6700     |
# |    time_elapsed       | 2513     |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -9.33    |
# |    explained_variance | -0.0136  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -43.4    |
# |    std                | 25.7     |
# |    value_loss         | 87.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.1     |
# |    ep_rew_mean        | -27      |
# |    success_rate       | 0        |
# ...
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 47500    |
# |    time_elapsed       | 35464    |
# |    total_timesteps    | 237500   |
# | train/                |          |
# |    entropy_loss       | -30.6    |
# |    explained_variance | 0.236    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47499    |
# |    policy_loss        | 12.1     |
# |    std                | 1.09e+06 |
# |    value_loss         | 0.241    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.77     |
# |    ep_rew_mean        | -25.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 47600    |
# |    time_elapsed       | 35545    |
# |    total_timesteps    | 238000   |
# | train/                |          |
# |    entropy_loss       | -30.7    |
# |    explained_variance | 0.817    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47599    |
# |    policy_loss        | -15.2    |
# |    std                | 1.11e+06 |
# |    value_loss         | 0.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.56     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 47700    |
# |    time_elapsed       | 35626    |
# |    total_timesteps    | 238500   |
# | train/                |          |
# |    entropy_loss       | -30.7    |
# |    explained_variance | 0.704    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47699    |
# |    policy_loss        | 5.86     |
# |    std                | 1.15e+06 |
# |    value_loss         | 0.0692   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.8      |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 47800    |
# |    time_elapsed       | 35704    |
# |    total_timesteps    | 239000   |
# | train/                |          |
# |    entropy_loss       | -30.8    |
# |    explained_variance | -3.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | 29.6     |
# |    std                | 1.17e+06 |
# |    value_loss         | 1.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.11     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 47900    |
# |    time_elapsed       | 35784    |
# |    total_timesteps    | 239500   |
# | train/                |          |
# |    entropy_loss       | -30.8    |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | -6.4     |
# |    std                | 1.19e+06 |
# |    value_loss         | 0.0503   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.34     |
# |    ep_rew_mean        | -25.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48000    |
# |    time_elapsed       | 35870    |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -30.9    |
# |    explained_variance | -0.00899 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | -28.8    |
# |    std                | 1.23e+06 |
# |    value_loss         | 1.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.33     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48100    |
# |    time_elapsed       | 35950    |
# |    total_timesteps    | 240500   |
# | train/                |          |
# |    entropy_loss       | -30.9    |
# |    explained_variance | -1.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 18.9     |
# |    std                | 1.26e+06 |
# |    value_loss         | 0.577    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.45     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48200    |
# |    time_elapsed       | 36031    |
# |    total_timesteps    | 241000   |
# | train/                |          |
# |    entropy_loss       | -31      |
# |    explained_variance | -1.19    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | 25.2     |
# |    std                | 1.29e+06 |
# |    value_loss         | 0.896    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.85     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48300    |
# |    time_elapsed       | 36114    |
# |    total_timesteps    | 241500   |
# | train/                |          |
# |    entropy_loss       | -31      |
# |    explained_variance | 0.687    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -8.9     |
# |    std                | 1.31e+06 |
# |    value_loss         | 0.158    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.1      |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48400    |
# |    time_elapsed       | 36202    |
# |    total_timesteps    | 242000   |
# | train/                |          |
# |    entropy_loss       | -31.1    |
# |    explained_variance | 0.588    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | 12.5     |
# |    std                | 1.35e+06 |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.01     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48500    |
# |    time_elapsed       | 36287    |
# |    total_timesteps    | 242500   |
# | train/                |          |
# |    entropy_loss       | -31.1    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | -6.14    |
# |    std                | 1.39e+06 |
# |    value_loss         | 0.0507   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.94     |
# |    ep_rew_mean        | -25.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48600    |
# |    time_elapsed       | 36365    |
# |    total_timesteps    | 243000   |
# | train/                |          |
# |    entropy_loss       | -31.2    |
# |    explained_variance | 0.781    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | 9.34     |
# |    std                | 1.42e+06 |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.71     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48700    |
# |    time_elapsed       | 36447    |
# |    total_timesteps    | 243500   |
# | train/                |          |
# |    entropy_loss       | -31.2    |
# |    explained_variance | 0.587    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | -4.93    |
# |    std                | 1.45e+06 |
# |    value_loss         | 0.227    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.49     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48800    |
# |    time_elapsed       | 36533    |
# |    total_timesteps    | 244000   |
# | train/                |          |
# |    entropy_loss       | -31.3    |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | -17.5    |
# |    std                | 1.48e+06 |
# |    value_loss         | 0.319    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.87     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 48900    |
# |    time_elapsed       | 36615    |
# |    total_timesteps    | 244500   |
# | train/                |          |
# |    entropy_loss       | -31.3    |
# |    explained_variance | 0.117    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | -20.9    |
# |    std                | 1.51e+06 |
# |    value_loss         | 0.457    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.17     |
# |    ep_rew_mean        | -25.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49000    |
# |    time_elapsed       | 36704    |
# |    total_timesteps    | 245000   |
# | train/                |          |
# |    entropy_loss       | -31.3    |
# |    explained_variance | -2.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | 35       |
# |    std                | 1.55e+06 |
# |    value_loss         | 1.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.24     |
# |    ep_rew_mean        | -25.3    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49100    |
# |    time_elapsed       | 36779    |
# |    total_timesteps    | 245500   |
# | train/                |          |
# |    entropy_loss       | -31.4    |
# |    explained_variance | 0.721    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | 9.77     |
# |    std                | 1.58e+06 |
# |    value_loss         | 0.312    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.36     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49200    |
# |    time_elapsed       | 36873    |
# |    total_timesteps    | 246000   |
# | train/                |          |
# |    entropy_loss       | -31.4    |
# |    explained_variance | 0.264    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -12.8    |
# |    std                | 1.62e+06 |
# |    value_loss         | 0.194    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.33     |
# |    ep_rew_mean        | -25.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49300    |
# |    time_elapsed       | 36955    |
# |    total_timesteps    | 246500   |
# | train/                |          |
# |    entropy_loss       | -31.5    |
# |    explained_variance | 0.886    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.561   |
# |    std                | 1.68e+06 |
# |    value_loss         | 0.057    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.12     |
# |    ep_rew_mean        | -25.1    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49400    |
# |    time_elapsed       | 37052    |
# |    total_timesteps    | 247000   |
# | train/                |          |
# |    entropy_loss       | -31.6    |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | -5.11    |
# |    std                | 1.72e+06 |
# |    value_loss         | 0.0377   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.36     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49500    |
# |    time_elapsed       | 37135    |
# |    total_timesteps    | 247500   |
# | train/                |          |
# |    entropy_loss       | -31.6    |
# |    explained_variance | 0.216    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | -9.79    |
# |    std                | 1.76e+06 |
# |    value_loss         | 0.168    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.95     |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49600    |
# |    time_elapsed       | 37218    |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -31.6    |
# |    explained_variance | -2.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | 39.3     |
# |    std                | 1.8e+06  |
# |    value_loss         | 1.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.2      |
# |    ep_rew_mean        | -25.2    |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 49700    |
# |    time_elapsed       | 37294    |
# |    total_timesteps    | 248500   |
# | train/                |          |
# |    entropy_loss       | -31.7    |
# |    explained_variance | -1.99    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | 29.6     |
# |    std                | 1.82e+06 |
# |    value_loss         | 1.18     |
# ------------------------------------

# %%
# -------------------------------------------------------------
# Inferensi dan evaluasi dengan custom evaluasi metrik (untuk PPO)
# -------------------------------------------------------------
import numpy as np  # Tambahkan numpy untuk analisis statistik
import gymnasium as gym
from twsbr_env.envs import TwsbrEnv  # Import environment
from stable_baselines3 import A2C

# Muat kembali lingkungan dan model
env = gym.make("TwsbrEnv-v0",
               render_mode="human",
               action_type="continuous"  # Action type
               )

model = A2C.load("twsbr_a2c")

# Mulai evaluasi
total_rewards = []
episode_lengths = []
episode_reward = 0
episode_length = 0

obs, info = env.reset()
terminated = False
truncated = False

for _ in range(10000):  # Jumlah langkah yang akan dilakukan selama evaluasi
    # Pilih tindakan berdasarkan model
    action, _states = model.predict(obs, deterministic=True)

    # Lakukan aksi di lingkungan
    obs, reward, terminated, truncated, info = env.step(action)
    
    episode_reward += reward
    episode_length += 1

    # Render visualisasi (jika diinginkan)
    # Reset episode jika selesai
    if terminated or truncated:
        #print(f"\r {obs}, {episode_length}", end="")  # Uncomment for debugging
        total_rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        obs, info = env.reset()
        episode_reward = 0
        episode_length = 0

# Analisis hasil evaluasi
average_reward = np.mean(total_rewards)
average_length = np.mean(episode_lengths)

print(f"Average Reward per Episode: {average_reward:.2f}")
print(f"Average Episode Length: {average_length:.2f}")

# Menutup lingkungan
env.close()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 43
#      41 total_rewards.append(episode_reward)
#      42 episode_lengths.append(episode_length)
# ---> 43 obs, info = env.reset()
#      44 episode_reward = 0
#      45 episode_length = 0
#
# File c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\gymnasium\wrappers\order_enforcing.py:61, in OrderEnforcing.reset(self, **kwargs)
#      59 """Resets the environment with `kwargs`."""
#      60 self._has_reset = True
# ---> 61 return self.env.reset(**kwargs)
#
# File c:\Users\User\anaconda3\envs\robot_sim\lib\site-packages\gymnasium\wrappers\env_checker.py:59, in PassiveEnvChecker.reset(self, **kwargs)
#      57     return env_reset_passive_checker(self.env, **kwargs)
#      58 else:
# ---> 59     return self.env.reset(**kwargs)
#
# File c:\Users\User\Documents\DATA\Fitra Nurmayadi\TWSBR\twsbr\twsbr_env\envs\TwsbrEnv.py:81, in TwsbrEnv.reset(self, seed, options)
#      79 def reset(self, seed=None, options=None):
#      80     super().reset(seed=seed)
# ---> 81     self.load_robot()
#      82     self.step_counter = 0
#      83     self.initialize_wheel_variables()
#
# File c:\Users\User\Documents\DATA\Fitra Nurmayadi\TWSBR\twsbr\twsbr_env\envs\TwsbrEnv.py:100, in TwsbrEnv.load_robot(self)
#      98 self._bullet_client.removeBody(self.robot_id)
#      99 #self._bullet_client.resetSimulation()
# --> 100 self._init_physics_client()
#
# File c:\Users\User\Documents\DATA\Fitra Nurmayadi\TWSBR\twsbr\twsbr_env\envs\TwsbrEnv.py:151, in TwsbrEnv._init_physics_client(self)
#     137     #start_position, start_orientation = [0.0, 0.0, 0.0], pybullet.getQuaternionFromEuler([0, 0, 0])
#     138
#     139
#    (...)
#     146     #self.robot_spinning_friction = np.random.uniform(0.5, 1.0)  # lateral friction
#     147     #self.robot_wheels_inertial = np.random.uniform(0.0, 0.001, size=3)  # Random inertia [Ixx, Iyy, Izz]
#     149 self.robot_id = self._bullet_client.loadURDF(self.urdf_file_name, basePosition=start_position, baseOrientation=start_orientation)
# --> 151 self._bullet_client.setJointMotorControl2(self.robot_id, self.LEFT_WHEEL_JOINT_IDX, pybullet.VELOCITY_CONTROL, targetVelocity=0)
#     152 self._bullet_client.setJointMotorControl2(self.robot_id, self.RIGHT_WHEEL_JOINT_IDX, pybullet.VELOCITY_CONTROL, targetVelocity=0)
#
# error: Not connected to physics server.
